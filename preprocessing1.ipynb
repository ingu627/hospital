# %%
import numpy as np
import pandas as pd
import os

# %%
df1=pd.read_csv('./data/all_hospital.csv', encoding='cp949');df1
# Out:
#              요양기관명 종별코드명 시도코드명  \
# 0     가톨릭대학교인천성모병원  상급종합    인천
# 1           강릉아산병원  상급종합    강원
# 2           강북삼성병원  상급종합    서울
# 3          건국대학교병원  상급종합    서울
# 4          경북대학교병원  상급종합    대구
# ...            ...   ...   ...
# 1772          희연병원    병원    경남
# 1773        히즈메디병원    병원    경기
# 1774         힘내라병원    병원    부산
# 1775          힘센병원    병원    대구
# 1776        힘플러스병원    병원    전남
#
#                                                      주소         x좌표        y좌표
# 0                                인천광역시 부평구 동수로 56 (부평동)  126.724899  37.484831
# 1                                 강원도 강릉시 사천면 방동길 38 ()  128.857841  37.818433
# 2                                서울특별시 종로구 새문안로 29 (평동)  126.967750  37.568408
# 3                             서울특별시 광진구 능동로 120-1 (화양동)  127.071828  37.540376
# 4                     대구광역시 중구 동덕로 130 (삼덕동2가, 경북대학교병원)  128.604125  35.866774
# ...                                                 ...         ...        ...
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1777 entries, 0 to 1776
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   요양기관명   1777 non-null   object
#  1   종별코드명   1777 non-null   object
#  2   시도코드명   1777 non-null   object
#  3   주소      1777 non-null   object
#  4   x좌표     1677 non-null   float64
#  5   y좌표     1677 non-null   float64
# dtypes: float64(2), object(4)
# memory usage: 83.4+ KB
